# %%
# Random Forest Classification Script for Recipe Reviews Dataset
# Implements data exploration, preprocessing, hyperparameter tuning, and evaluation
# Includes outlier handling, feature importance, holdout vs. CV comparison, parameter sensitivity,
# preprocessing strategy comparison, runtime analysis, report-ready summaries, and trend identification

# Cell 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
import time
import os
# %matplotlib inline

# %%
# Cell 2: Data Exploration
def detect_outliers(df, numerical_cols):
    """Detect and visualize outliers using IQR method for numerical features."""
    print("\nOutlier Analysis:")
    for col in numerical_cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
        print(f"{col}: {len(outliers)} outliers")
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[col])
        plt.title(f'Boxplot of {col}')
        plt.savefig(f'outliers_{col}_recipe.png')
        plt.show()

def explore_dataset(df):
    """Explore dataset structure, class distribution, missing values, and outliers.
    Saves visualizations (class distribution, correlation heatmap, boxplots) for the report.
    """
    print("\nDataset Shape:", df.shape)
    print("\nFirst 5 Rows:\n", df.head())
    print("\nData Types:\n", df.dtypes)
    
    # Class distribution
    class_counts = df['stars'].value_counts()
    print("\nClass Distribution (Stars):\n", class_counts)
    plt.figure(figsize=(8, 6))
    sns.barplot(x=class_counts.index, y=class_counts.values)
    plt.title('Stars Rating Distribution')
    plt.xlabel('Stars (0: No Rating, 1–5: Rating)')
    plt.ylabel('Number of Samples')
    plt.savefig('class_distribution_recipe.png')
    plt.show()
    
    # Missing values
    missing_values = df.isnull().sum()
    print("\nMissing Values:\n", missing_values[missing_values > 0])
    
    # Check for special missing value indicator (2)
    print("\nColumns with value 2 (potential missing values):\n", (df == 2).sum())
    
    # Feature statistics (numerical features only)
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    print("\nFeature Statistics (Numerical):\n", df[numerical_cols].describe())
    
    # Feature correlations (numerical features)
    plt.figure(figsize=(12, 8))
    sns.heatmap(df[numerical_cols].corr(), cmap='coolwarm', annot=True)
    plt.title('Numerical Feature Correlation Heatmap')
    plt.savefig('feature_correlation_recipe.png')
    plt.show()
    
    # Outlier detection
    detect_outliers(df, numerical_cols)

# Load dataset with error handling
data_path = 'Recipe Reviews and User Feedback Dataset.csv'  
try:
    df = pd.read_csv(data_path)
    if 'stars' not in df.columns:
        raise ValueError("Dataset must contain 'stars' column")
except FileNotFoundError:
    print(f"Error: File {data_path} not found")
    exit(1)
except Exception as e:
    print(f"Error loading data: {e}")
    exit(1)

# Explore dataset
explore_dataset(df)
# Out:
# Dataset Shape: (18182, 15)
#
# First 5 Rows:
#     Unnamed: 0  recipe_number  recipe_code         recipe_name  \
# 0           0              1        14299  Creamy White Chili
# 1           1              1        14299  Creamy White Chili
# 2           2              1        14299  Creamy White Chili
# 3           3              1        14299  Creamy White Chili
# 4           4              1        14299  Creamy White Chili
#
#                                         comment_id         user_id  \
# 0  sp_aUSaElGf_14299_c_2G3aneMRgRMZwXqIHmSdXSG1hEM  u_9iFLIhMa8QaG
# 1  sp_aUSaElGf_14299_c_2FsPC83HtzCsQAtOxlbL6RcaPbY  u_Lu6p25tmE77j
# 2  sp_aUSaElGf_14299_c_2FPrSGyTv7PQkZq37j92r9mYGkP  u_s0LwgpZ8Jsqq
# 3  sp_aUSaElGf_14299_c_2DzdSIgV9qNiuBaLoZ7JQaartoC  u_fqrybAdYjgjG
# 4  sp_aUSaElGf_14299_c_2DtZJuRQYeTFwXBoZRfRhBPEXjI  u_XXWKwVhKZD69
#
#     user_name  user_reputation  created_at  reply_count  thumbs_up  \
# 0     Jeri326                1  1665619889            0          0
# 1     Mark467               50  1665277687            0          7
# 2  Barbara566               10  1664404557            0          3
# 3  jeansch123                1  1661787808            2          2
# 4    camper77               10  1664913823            1          7
#
#    thumbs_down  stars  best_score  \
# 0            0      5         527
# 1            0      5         724
# 2            0      5         710
# 3            0      0         581
# 4            0      0         820
#
#                                                 text
# 0  I tweaked it a little, removed onions because ...
# 1  Bush used to have a white chili bean and it ma...
# 2  I have a very complicated white chicken chili ...
# 3  In your introduction, you mentioned cream chee...
# 4  Wonderful! I made this for a &#34;Chili/Stew&#...
#
# Data Types:
#  Unnamed: 0          int64
# recipe_number       int64
# recipe_code         int64
# recipe_name        object
# comment_id         object
# user_id            object
# user_name          object
# user_reputation     int64
# created_at          int64
# reply_count         int64
# thumbs_up           int64
# thumbs_down         int64
# stars               int64
# best_score          int64
# text               object
# dtype: object
#
# Class Distribution (Stars):
#  stars
# 5    13829
# 0     1696
# 4     1655
# 3      490
# 1      280
# 2      232
# Name: count, dtype: int64
# Missing Values:
#  text    2
# dtype: int64
#
# Columns with value 2 (potential missing values):
#  Unnamed: 0         100
# recipe_number      509
# recipe_code          0
# recipe_name          0
# comment_id           0
# user_id              0
# user_name            0
# user_reputation      0
# created_at           0
# reply_count         24
# thumbs_up          624
# thumbs_down        388
# stars              232
# best_score           0
# text                 0
# dtype: int64
#
# Feature Statistics (Numerical):
#           Unnamed: 0  recipe_number    recipe_code  user_reputation  \
# count  18182.000000   18182.000000   18182.000000     18182.000000
# mean     121.465295      38.689363   21773.667253         2.159608
# std      116.747893      29.786647   23965.109637        10.014666
# min        0.000000       1.000000     386.000000         0.000000
# 25%       45.000000      12.000000    6086.000000         1.000000
# 50%       91.000000      33.000000   14600.000000         1.000000
# 75%      150.000000      64.000000   33121.000000         1.000000
# max      724.000000     100.000000  191775.000000       520.000000
#
#          created_at   reply_count     thumbs_up   thumbs_down         stars  \
# count  1.818200e+04  18182.000000  18182.000000  18182.000000  18182.000000
# mean   1.623710e+09      0.014630      1.089264      0.549335      4.288802
# std    5.468697e+06      0.137974      4.201004      3.470124      1.544786
# min    1.613035e+09      0.000000      0.000000      0.000000      0.000000
# 25%    1.622717e+09      0.000000      0.000000      0.000000      5.000000
# 50%    1.622718e+09      0.000000      0.000000      0.000000      5.000000
# 75%    1.622718e+09      0.000000      0.000000      0.000000      5.000000
# max    1.665756e+09      3.000000    106.000000    126.000000      5.000000
#
#          best_score
# count  18182.000000
# mean     153.162138
# std      141.075316
# min        0.000000
# 25%      100.000000
# 50%      100.000000
# 75%      100.000000
# max      946.000000
# Outlier Analysis:
# Unnamed: 0: 1383 outliers
# recipe_number: 0 outliers
# recipe_code: 656 outliers
# user_reputation: 1246 outliers
# created_at: 1487 outliers
# reply_count: 230 outliers
# thumbs_up: 4080 outliers
# thumbs_down: 2396 outliers
# stars: 4353 outliers
# best_score: 4180 outliers

# %%
# Cell 3: Preprocessing
def preprocess_data(df, scaling=True, imputation_strategy='median', sample_fraction=1.0):
    """Preprocess the dataset: sample, handle missing values, encode features, scale, split data.
    Args:
        df: Input DataFrame
        scaling: Whether to apply StandardScaler (True) or not (False)
        imputation_strategy: Strategy for numerical imputation ('median' or 'mean')
        sample_fraction: Fraction of data to sample (e.g., 0.5 for 50%)
    Returns:
        X_train, X_test, y_train, y_test, y, feature_cols
    """
    # Subsample dataset
    sampled_df = df.sample(frac=sample_fraction, random_state=42)
    
    # Drop text and non-predictive ID columns
    drop_cols = ['text', 'comment_id', 'user_id', 'user_name']
    sampled_df = sampled_df.drop(columns=drop_cols)
    
    # Replace special missing value indicator (2) with NaN
    sampled_df = sampled_df.replace(2, np.nan)
    
    # Drop rows where target 'stars' is NaN
    sampled_df = sampled_df.dropna(subset=['stars'])
    
    # Separate features and target
    feature_cols = [col for col in sampled_df.columns if col != 'stars']
    X = sampled_df[feature_cols]
    y = sampled_df['stars']
    
    # Handle categorical features
    categorical_cols = X.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        le = LabelEncoder()
        X[col] = le.fit_transform(X[col].astype(str))
    
    # Impute missing values for numerical features
    numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
    if len(numerical_cols) > 0:
        num_imputer = SimpleImputer(strategy=imputation_strategy)
        X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
    
    # Scale numerical features if specified
    if scaling:
        scaler = StandardScaler()
        X_processed = scaler.fit_transform(X)
    else:
        X_processed = X.values
    
    # Split data (80% train, 20% test, stratified)
    X_train, X_test, y_train, y_test = train_test_split(
        X_processed, y, test_size=0.2, random_state=42, stratify=y
    )
    print(f"\nDataset size: {sampled_df.shape[0]}, Training samples: {X_train.shape[0]}, Testing samples: {X_test.shape[0]}")
    
    return X_train, X_test, y_train, y_test, y, feature_cols

# %%
# Cell 4: Random Forest Experiments
def run_rf_experiments(X_train, y_train, X_test, y_test, class_names, feature_cols):
    """Run Random Forest experiments with different parameter settings.
    Args:
        X_train, y_train, X_test, y_test: Training and testing data
        class_names: List of class names for visualization
        feature_cols: List of feature column names
    Returns:
        List of results dictionaries
    """
    # Define parameter grid
    param_grid = {
        'n_estimators': [50, 100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5],
        'max_features': ['sqrt', 'log2'],
        'min_samples_leaf': [1, 2]
    }
    
    # Initialize results storage
    results = []
    
    # Experiment with parameter settings
    print("\n=== Random Forest Experiments ===")
    for n_estimators in param_grid['n_estimators']:
        for max_depth in param_grid['max_depth']:
            for min_samples_split in param_grid['min_samples_split']:
                for max_features in param_grid['max_features']:
                    for min_samples_leaf in param_grid['min_samples_leaf']:
                        print(f"\nTesting: n_estimators={n_estimators}, max_depth={max_depth}, min_samples_split={min_samples_split}, max_features={max_features}, min_samples_leaf={min_samples_leaf}")
                        
                        # Initialize classifier with balanced class weights to handle potential imbalance
                        rf_classifier = RandomForestClassifier(
                            n_estimators=n_estimators,
                            max_depth=max_depth,
                            min_samples_split=min_samples_split,
                            max_features=max_features,
                            min_samples_leaf=min_samples_leaf,
                            random_state=42,
                            class_weight='balanced'
                        )
                        
                        # Measure training time
                        start_time = time.time()
                        rf_classifier.fit(X_train, y_train)
                        training_time = time.time() - start_time
                        
                        # Holdout evaluation
                        start_time = time.time()
                        predictions = rf_classifier.predict(X_test)
                        prediction_time = time.time() - start_time
                        
                        # Performance metrics
                        accuracy = accuracy_score(y_test, predictions)
                        f1 = f1_score(y_test, predictions, average='weighted')
                        roc_auc = roc_auc_score(y_test, rf_classifier.predict_proba(X_test), multi_class='ovr')
                        
                        # Cross-validation (5-fold)
                        cv_scores = cross_val_score(rf_classifier, X_train, y_train, cv=5, scoring='accuracy')
                        cv_accuracy = np.mean(cv_scores)
                        
                        # Store results
                        results.append({
                            'n_estimators': n_estimators,
                            'max_depth': max_depth,
                            'min_samples_split': min_samples_split,
                            'max_features': max_features,
                            'min_samples_leaf': min_samples_leaf,
                            'accuracy': accuracy,
                            'f1_score': f1,
                            'roc_auc': roc_auc,
                            'cv_accuracy': cv_accuracy,
                            'training_time': training_time,
                            'prediction_time': prediction_time
                        })
                        
                        # Print results
                        print(f"Accuracy: {accuracy:.2f}, F1-Score: {f1:.2f}, ROC-AUC: {roc_auc:.2f}, CV Accuracy: {cv_accuracy:.2f}")
                        print(f"Training Time: {training_time:.2f}s, Prediction Time: {prediction_time:.2f}s")
    
    return results

# %%
# Cell 5: Visualization and Analysis
def plot_feature_importance(model, feature_cols):
    """Plot feature importances of the Random Forest model."""
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]
    plt.figure(figsize=(10, 6))
    plt.bar(range(len(importances)), importances[indices], align='center')
    plt.xticks(range(len(importances)), [feature_cols[i] for i in indices], rotation=45)
    plt.title('Feature Importance')
    plt.tight_layout()
    plt.savefig('rf_feature_importance_recipe.png')
    plt.show()

def compare_holdout_cv(results_df):
    """Compare holdout and cross-validation accuracies."""
    results_df['holdout_cv_diff'] = results_df['accuracy'] - results_df['cv_accuracy']
    print("\nHoldout vs. CV Accuracy Difference:\n", results_df[['accuracy', 'cv_accuracy', 'holdout_cv_diff']].describe())
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=results_df, x='cv_accuracy', y='accuracy', hue='n_estimators')
    plt.plot([0, 1], [0, 1], 'r--')  # Diagonal line
    plt.title('Holdout vs. Cross-Validation Accuracy')
    plt.savefig('rf_holdout_vs_cv_recipe.png')
    plt.show()

def analyze_parameter_sensitivity(results_df):
    """Analyze sensitivity of accuracy to parameter settings."""
    print("\nParameter Sensitivity (Std of Accuracy):")
    for param in ['n_estimators', 'max_depth', 'min_samples_split', 'max_features', 'min_samples_leaf']:
        grouped = results_df.groupby(param)['accuracy'].std()
        print(f"{param}:\n{grouped}")

def summarize_best_models(results_df, top_n=5):
    """Summarize top N models by accuracy."""
    top_models = results_df.nlargest(top_n, 'accuracy')[['n_estimators', 'max_depth', 'min_samples_split', 'max_features', 'min_samples_leaf', 'accuracy', 'f1_score', 'roc_auc', 'cv_accuracy', 'training_time']]
    print("\nTop 5 Models:\n", top_models)
    top_models.to_csv('rf_top_models_recipe.csv', index=False)

def identify_trends(results_df):
    """Identify common parameter values in top 10 models."""
    print("\nMost Common Parameters in Top 10 Models:")
    top_10 = results_df.nlargest(10, 'accuracy')
    for param in ['n_estimators', 'max_depth', 'min_samples_split', 'max_features', 'min_samples_leaf']:
        print(f"{param}: {top_10[param].value_counts().head(1)}")

def visualize_and_save_results(results, X_train, y_train, X_test, y_test, class_names, feature_cols):
    """Visualize results, save to CSV, and generate report-ready summaries.
    Includes confusion matrix, classification report, parameter sensitivity, and feature importance.
    """
    # Convert results to DataFrame
    results_df = pd.DataFrame(results)
    print("\nSummary of Results:\n", results_df)
    
    # Additional analyses
    summarize_best_models(results_df)
    compare_holdout_cv(results_df)
    analyze_parameter_sensitivity(results_df)
    identify_trends(results_df)
    
    # Save results
    results_df.to_csv("rf_results_recipe.csv", index=False)
    
    # Find best model
    best_idx = results_df['accuracy'].idxmax()
    max_depth = results_df.loc[best_idx]['max_depth']
    max_depth = None if pd.isna(max_depth) else int(max_depth)
    
    best_rf = RandomForestClassifier(
        n_estimators=int(results_df.loc[best_idx]['n_estimators']),
        max_depth=max_depth,
        min_samples_split=int(results_df.loc[best_idx]['min_samples_split']),
        max_features=results_df.loc[best_idx]['max_features'],
        min_samples_leaf=int(results_df.loc[best_idx]['min_samples_leaf']),
        random_state=42,
        class_weight='balanced'
    )
    best_rf.fit(X_train, y_train)
    predictions = best_rf.predict(X_test)
    
    # Feature importance
    plot_feature_importance(best_rf, feature_cols)
    
    # Confusion matrix
    cm = confusion_matrix(y_test, predictions)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_names, yticklabels=class_names, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Best Random Forest Confusion Matrix')
    plt.savefig('rf_confusion_matrix_recipe.png')
    plt.show()
    
    # Classification report
    print("\nClassification Report for Best Model:")
    print(classification_report(y_test, predictions, target_names=class_names))
    
    # Plot accuracy vs. n_estimators
    plt.figure(figsize=(8, 6))
    sns.lineplot(data=results_df, x='n_estimators', y='accuracy', hue='max_depth', style='min_samples_split')
    plt.title('Accuracy vs. n_estimators')
    plt.savefig('rf_accuracy_vs_estimators_recipe.png')
    plt.show()
    
    # Plot accuracy vs. max_depth
    plt.figure(figsize=(8, 6))
    sns.lineplot(data=results_df, x='max_depth', y='accuracy', hue='n_estimators', style='min_samples_split')
    plt.title('Accuracy vs. max_depth')
    plt.savefig('rf_accuracy_vs_max_depth_recipe.png')
    plt.show()
    
    # Plot accuracy vs. max_features
    plt.figure(figsize=(8, 6))
    sns.lineplot(data=results_df, x='max_features', y='accuracy', hue='n_estimators', style='min_samples_leaf')
    plt.title('Accuracy vs. max_features')
    plt.savefig('rf_accuracy_vs_max_features_recipe.png')
    plt.show()

# %%
# Cell 6: Main Execution
# Define class names dynamically based on unique values in y
X_train, X_test, y_train, y_test, y, feature_cols = preprocess_data(df)  # Initial preprocessing to get y
class_names = [f"{int(label)} Star{'s' if label != 1 else ''}" for label in sorted(y.unique())]
print("Class names:", class_names)

# Run experiments for different dataset sizes, scaling, and imputation strategies
for scaling in [True, False]:
    for imputation_strategy in ['median', 'mean']:
        for frac in [0.5, 1.0]:
            print(f"\n=== Experiments: Scaling={scaling}, Imputation={imputation_strategy}, Fraction={frac} ===")
            X_train, X_test, y_train, y_test, y, feature_cols = preprocess_data(
                df, scaling=scaling, imputation_strategy=imputation_strategy, sample_fraction=frac
            )
            results = run_rf_experiments(X_train, y_train, X_test, y_test, class_names, feature_cols)
            visualize_and_save_results(results, X_train, y_train, X_test, y_test, class_names, feature_cols)
            results_df = pd.DataFrame(results)
            results_df.to_csv(f"rf_results_recipe_scaling_{scaling}_imputation_{imputation_strategy}_frac_{frac}.csv", index=False)
# Out:
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
# Dataset size: 17950, Training samples: 14360, Testing samples: 3590
# Class names: ['0 Stars', '1 Star', '3 Stars', '4 Stars', '5 Stars']
#
# === Experiments: Scaling=True, Imputation=median, Fraction=0.5 ===
#
# Dataset size: 8988, Training samples: 7190, Testing samples: 1798
#
# === Random Forest Experiments ===
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 1.93s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.73
# Training Time: 1.39s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 1.49s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.73
# Training Time: 1.00s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 1.15s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.73
# Training Time: 0.76s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 0.77s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.73
# Training Time: 0.96s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.62, CV Accuracy: 0.60
# Training Time: 0.68s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.57
# Training Time: 0.62s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.62, CV Accuracy: 0.60
# Training Time: 0.50s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.57
# Training Time: 0.64s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.54, F1-Score: 0.59, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.86s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.53, F1-Score: 0.58, ROC-AUC: 0.64, CV Accuracy: 0.57
# Training Time: 0.48s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.54, F1-Score: 0.59, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.60s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.53, F1-Score: 0.58, ROC-AUC: 0.64, CV Accuracy: 0.57
# Training Time: 0.77s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.65, CV Accuracy: 0.76
# Training Time: 1.06s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.66, CV Accuracy: 0.73
# Training Time: 0.76s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.65, CV Accuracy: 0.76
# Training Time: 0.80s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.66, CV Accuracy: 0.73
# Training Time: 1.53s, Prediction Time: 0.05s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 1.10s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 0.97s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 1.56s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 1.14s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 2.83s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 2.67s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 2.69s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 1.38s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 2.26s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 1.89s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 2.04s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 1.60s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.58, F1-Score: 0.61, ROC-AUC: 0.62, CV Accuracy: 0.61
# Training Time: 0.96s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 1.22s, Prediction Time: 0.06s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.58, F1-Score: 0.61, ROC-AUC: 0.62, CV Accuracy: 0.61
# Training Time: 1.67s, Prediction Time: 0.03s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 1.13s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.59
# Training Time: 1.15s, Prediction Time: 0.03s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.58
# Training Time: 1.33s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.59
# Training Time: 1.62s, Prediction Time: 0.03s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.58
# Training Time: 1.26s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 1.69s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 1.75s, Prediction Time: 0.04s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 2.07s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 2.40s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 2.48s, Prediction Time: 0.21s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 2.61s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 2.36s, Prediction Time: 0.08s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 2.90s, Prediction Time: 0.06s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.76
# Training Time: 6.67s, Prediction Time: 0.26s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 4.23s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.76
# Training Time: 4.85s, Prediction Time: 0.15s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 4.65s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 3.54s, Prediction Time: 0.14s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 4.52s, Prediction Time: 0.15s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 5.12s, Prediction Time: 0.19s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 5.15s, Prediction Time: 0.13s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.59, F1-Score: 0.62, ROC-AUC: 0.62, CV Accuracy: 0.61
# Training Time: 3.23s, Prediction Time: 0.13s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.64, CV Accuracy: 0.59
# Training Time: 3.32s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.59, F1-Score: 0.62, ROC-AUC: 0.62, CV Accuracy: 0.61
# Training Time: 3.68s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.64, CV Accuracy: 0.59
# Training Time: 2.35s, Prediction Time: 0.08s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.63, CV Accuracy: 0.59
# Training Time: 3.25s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.56, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.59
# Training Time: 3.50s, Prediction Time: 0.11s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.57, F1-Score: 0.61, ROC-AUC: 0.63, CV Accuracy: 0.59
# Training Time: 2.34s, Prediction Time: 0.06s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.56, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.59
# Training Time: 1.93s, Prediction Time: 0.07s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.67, CV Accuracy: 0.76
# Training Time: 3.43s, Prediction Time: 0.11s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 3.06s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.67, CV Accuracy: 0.76
# Training Time: 6.23s, Prediction Time: 0.16s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 3.04s, Prediction Time: 0.09s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 4.87s, Prediction Time: 0.20s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 3.23s, Prediction Time: 0.09s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 3.83s, Prediction Time: 0.25s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 2.78s, Prediction Time: 0.10s
#
# Summary of Results:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 0             50        NaN                  2         sqrt                 1
# 1             50        NaN                  2         sqrt                 2
# 2             50        NaN                  2         log2                 1
# 3             50        NaN                  2         log2                 2
# 4             50        NaN                  5         sqrt                 1
# ..           ...        ...                ...          ...               ...
# 67           200       20.0                  2         log2                 2
# 68           200       20.0                  5         sqrt                 1
# 69           200       20.0                  5         sqrt                 2
# 70           200       20.0                  5         log2                 1
# 71           200       20.0                  5         log2                 2
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time  prediction_time
# 0   0.770300  0.708061  0.656017     0.763978       1.930558         0.059921
# 1   0.736930  0.695882  0.672314     0.734631       1.391409         0.030972
# 2   0.770300  0.708061  0.656017     0.763978       1.488594         0.041299
# 3   0.736930  0.695882  0.672314     0.734631       0.998972         0.032076
# 4   0.748053  0.699954  0.660508     0.742420       1.152654         0.024139
# ..       ...       ...       ...          ...            ...              ...
# 67  0.742492  0.699686  0.670646     0.743672       3.043843         0.091029
# 68  0.746941  0.699405  0.672955     0.744089       4.874961         0.199187
# 69  0.730256  0.693145  0.679849     0.736718       3.227328         0.090150
# 70  0.746941  0.699405  0.672955     0.744089       3.833780         0.249557
# 71  0.730256  0.693145  0.679849     0.736718       2.779680         0.098651
#
# [72 rows x 11 columns]
#
# Top 5 Models:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 24           100        NaN                  2         sqrt                 1
# 26           100        NaN                  2         log2                 1
# 64           200       20.0                  2         sqrt                 1
# 66           200       20.0                  2         log2                 1
# 0             50        NaN                  2         sqrt                 1
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time
# 24  0.771969  0.704666  0.660865     0.764534       2.834753
# 26  0.771969  0.704666  0.660865     0.764534       2.686220
# 64  0.771413  0.706402  0.674938     0.764812       3.428826
# 66  0.771413  0.706402  0.674938     0.764812       6.231803
# 0   0.770300  0.708061  0.656017     0.763978       1.930558
#
# Holdout vs. CV Accuracy Difference:
#          accuracy  cv_accuracy  holdout_cv_diff
# count  72.000000    72.000000        72.000000
# mean    0.685700     0.692648        -0.006948
# std     0.090122     0.075802         0.015045
# min     0.528365     0.570376        -0.042011
# 25%     0.572164     0.597253        -0.020984
# 50%     0.736652     0.735327         0.000766
# 75%     0.748053     0.744854         0.004447
# max     0.771969     0.764812         0.008131
# Parameter Sensitivity (Std of Accuracy):
# n_estimators:
# n_estimators
# 50     0.095697
# 100    0.091809
# 200    0.086206
# Name: accuracy, dtype: float64
# max_depth:
# max_depth
# 10.0    0.016747
# 20.0    0.015370
# Name: accuracy, dtype: float64
# min_samples_split:
# min_samples_split
# 2    0.088968
# 5    0.091752
# Name: accuracy, dtype: float64
# max_features:
# max_features
# log2    0.090763
# sqrt    0.090763
# Name: accuracy, dtype: float64
# min_samples_leaf:
# min_samples_leaf
# 1    0.092222
# 2    0.088089
# Name: accuracy, dtype: float64
#
# Most Common Parameters in Top 10 Models:
# n_estimators: n_estimators
# 100    4
# Name: count, dtype: int64
# max_depth: max_depth
# 20.0    4
# Name: count, dtype: int64
# min_samples_split: min_samples_split
# 2    10
# Name: count, dtype: int64
# max_features: max_features
# sqrt    5
# Name: count, dtype: int64
# min_samples_leaf: min_samples_leaf
# 1    10
# Name: count, dtype: int64
# Classification Report for Best Model:
#               precision    recall  f1-score   support
#
#      0 Stars       0.52      0.16      0.24       173
#       1 Star       0.50      0.15      0.23        27
#      3 Stars       0.00      0.00      0.00        51
#      4 Stars       0.21      0.03      0.05       160
#      5 Stars       0.79      0.97      0.87      1387
#
#     accuracy                           0.77      1798
#    macro avg       0.40      0.26      0.28      1798
# weighted avg       0.69      0.77      0.70      1798
# === Experiments: Scaling=True, Imputation=median, Fraction=1.0 ===
#
# Dataset size: 17950, Training samples: 14360, Testing samples: 3590
#
# === Random Forest Experiments ===
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.67, CV Accuracy: 0.77
# Training Time: 2.33s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 1.43s, Prediction Time: 0.05s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.67, CV Accuracy: 0.77
# Training Time: 6.85s, Prediction Time: 0.22s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 1.81s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 1.64s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 1.36s, Prediction Time: 0.05s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 1.78s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 1.46s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.65, CV Accuracy: 0.53
# Training Time: 1.15s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.49, F1-Score: 0.55, ROC-AUC: 0.66, CV Accuracy: 0.51
# Training Time: 1.12s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.65, CV Accuracy: 0.53
# Training Time: 1.62s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.49, F1-Score: 0.55, ROC-AUC: 0.66, CV Accuracy: 0.51
# Training Time: 1.74s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.51
# Training Time: 1.29s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.49, F1-Score: 0.55, ROC-AUC: 0.67, CV Accuracy: 0.51
# Training Time: 1.20s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.51
# Training Time: 1.24s, Prediction Time: 0.13s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.49, F1-Score: 0.55, ROC-AUC: 0.67, CV Accuracy: 0.51
# Training Time: 1.35s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.76
# Training Time: 2.40s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 2.20s, Prediction Time: 0.07s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.76
# Training Time: 1.76s, Prediction Time: 0.07s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 1.81s, Prediction Time: 0.06s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 1.37s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 1.44s, Prediction Time: 0.07s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 1.56s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 1.28s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.77
# Training Time: 3.08s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 2.67s, Prediction Time: 0.09s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.77
# Training Time: 3.01s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 2.67s, Prediction Time: 0.08s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 3.50s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 3.40s, Prediction Time: 0.48s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 3.34s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.74
# Training Time: 3.21s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.66, CV Accuracy: 0.54
# Training Time: 1.84s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 2.41s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.66, CV Accuracy: 0.54
# Training Time: 2.64s, Prediction Time: 0.06s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 2.66s, Prediction Time: 0.06s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.52
# Training Time: 1.84s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 2.68s, Prediction Time: 0.07s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.52
# Training Time: 1.95s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 1.65s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.76
# Training Time: 2.82s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 2.51s, Prediction Time: 0.09s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.76
# Training Time: 2.82s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 2.62s, Prediction Time: 0.09s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 2.86s, Prediction Time: 0.08s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 2.48s, Prediction Time: 0.07s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 3.09s, Prediction Time: 0.09s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 2.69s, Prediction Time: 0.08s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.77
# Training Time: 6.02s, Prediction Time: 0.24s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 6.75s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.77
# Training Time: 5.76s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 5.14s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 5.49s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 4.91s, Prediction Time: 0.17s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 5.53s, Prediction Time: 0.17s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 4.93s, Prediction Time: 0.17s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.52, F1-Score: 0.58, ROC-AUC: 0.66, CV Accuracy: 0.54
# Training Time: 3.39s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.52
# Training Time: 3.93s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.52, F1-Score: 0.58, ROC-AUC: 0.66, CV Accuracy: 0.54
# Training Time: 3.59s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.66, CV Accuracy: 0.52
# Training Time: 6.40s, Prediction Time: 0.30s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 3.74s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 3.13s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 3.38s, Prediction Time: 0.10s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.52
# Training Time: 3.36s, Prediction Time: 0.15s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.77
# Training Time: 6.91s, Prediction Time: 0.20s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 5.33s, Prediction Time: 0.17s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.77
# Training Time: 6.54s, Prediction Time: 0.18s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.74
# Training Time: 5.02s, Prediction Time: 0.16s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 6.11s, Prediction Time: 0.20s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 5.32s, Prediction Time: 0.16s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.71, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 5.98s, Prediction Time: 0.16s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 4.85s, Prediction Time: 0.16s
#
# Summary of Results:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 0             50        NaN                  2         sqrt                 1
# 1             50        NaN                  2         sqrt                 2
# 2             50        NaN                  2         log2                 1
# 3             50        NaN                  2         log2                 2
# 4             50        NaN                  5         sqrt                 1
# ..           ...        ...                ...          ...               ...
# 67           200       20.0                  2         log2                 2
# 68           200       20.0                  5         sqrt                 1
# 69           200       20.0                  5         sqrt                 2
# 70           200       20.0                  5         log2                 1
# 71           200       20.0                  5         log2                 2
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time  prediction_time
# 0   0.764903  0.706672  0.666219     0.765251       2.325206         0.056497
# 1   0.739833  0.705370  0.687332     0.742061       1.430645         0.049346
# 2   0.764903  0.706672  0.666219     0.765251       6.854259         0.221892
# 3   0.739833  0.705370  0.687332     0.742061       1.805954         0.055169
# 4   0.740947  0.703284  0.669094     0.749791       1.640879         0.043096
# ..       ...       ...       ...          ...            ...              ...
# 67  0.737326  0.706960  0.692219     0.739972       5.018600         0.164287
# 68  0.747075  0.710004  0.689922     0.749095       6.114249         0.200668
# 69  0.731476  0.703625  0.689519     0.734958       5.316132         0.161601
# 70  0.747075  0.710004  0.689922     0.749095       5.978474         0.164502
# 71  0.731476  0.703625  0.689519     0.734958       4.847346         0.157207
#
# [72 rows x 11 columns]
#
# Top 5 Models:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 48           200        NaN                  2         sqrt                 1
# 50           200        NaN                  2         log2                 1
# 24           100        NaN                  2         sqrt                 1
# 26           100        NaN                  2         log2                 1
# 0             50        NaN                  2         sqrt                 1
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time
# 48  0.770752  0.707762  0.687037     0.770961       6.023132
# 50  0.770752  0.707762  0.687037     0.770961       5.757410
# 24  0.767688  0.705852  0.675518     0.769568       3.084061
# 26  0.767688  0.705852  0.675518     0.769568       3.013358
# 0   0.764903  0.706672  0.666219     0.765251       2.325206
#
# Holdout vs. CV Accuracy Difference:
#          accuracy  cv_accuracy  holdout_cv_diff
# count  72.000000    72.000000        72.000000
# mean    0.663866     0.671969        -0.008103
# std     0.115873     0.107590         0.009341
# min     0.487187     0.505919        -0.031058
# 25%     0.511281     0.527698        -0.016278
# 50%     0.734680     0.736664        -0.004143
# 75%     0.746866     0.749269        -0.002019
# max     0.770752     0.770961         0.004039
# Parameter Sensitivity (Std of Accuracy):
# n_estimators:
# n_estimators
# 50     0.120645
# 100    0.117041
# 200    0.114627
# Name: accuracy, dtype: float64
# max_depth:
# max_depth
# 10.0    0.010221
# 20.0    0.014288
# Name: accuracy, dtype: float64
# min_samples_split:
# min_samples_split
# 2    0.119771
# 5    0.113347
# Name: accuracy, dtype: float64
# max_features:
# max_features
# log2    0.116698
# sqrt    0.116698
# Name: accuracy, dtype: float64
# min_samples_leaf:
# min_samples_leaf
# 1    0.118664
# 2    0.113996
# Name: accuracy, dtype: float64
#
# Most Common Parameters in Top 10 Models:
# n_estimators: n_estimators
# 200    4
# Name: count, dtype: int64
# max_depth: max_depth
# 20.0    4
# Name: count, dtype: int64
# min_samples_split: min_samples_split
# 2    10
# Name: count, dtype: int64
# max_features: max_features
# sqrt    5
# Name: count, dtype: int64
# min_samples_leaf: min_samples_leaf
# 1    10
# Name: count, dtype: int64
# Classification Report for Best Model:
#               precision    recall  f1-score   support
#
#      0 Stars       0.57      0.20      0.30       339
#       1 Star       0.46      0.21      0.29        56
#      3 Stars       0.17      0.01      0.02        98
#      4 Stars       0.16      0.02      0.04       331
#      5 Stars       0.79      0.97      0.87      2766
#
#     accuracy                           0.77      3590
#    macro avg       0.43      0.28      0.30      3590
# weighted avg       0.69      0.77      0.71      3590
# === Experiments: Scaling=True, Imputation=mean, Fraction=0.5 ===
#
# Dataset size: 8988, Training samples: 7190, Testing samples: 1798
#
# === Random Forest Experiments ===
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = le.fit_transform(X[col].astype(str))
# /var/folders/4y/rcqh5h6941d8_km_12_j1kd80000gq/T/ipykernel_1516/252330012.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[numerical_cols] = num_imputer.fit_transform(X[numerical_cols])
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.65, CV Accuracy: 0.76
# Training Time: 0.99s, Prediction Time: 0.03s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 0.83s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.77, F1-Score: 0.70, ROC-AUC: 0.65, CV Accuracy: 0.76
# Training Time: 0.77s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 0.68s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 0.72s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.66, CV Accuracy: 0.73
# Training Time: 0.67s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.75, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.74
# Training Time: 0.70s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.66, CV Accuracy: 0.73
# Training Time: 0.66s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.58, F1-Score: 0.62, ROC-AUC: 0.63, CV Accuracy: 0.61
# Training Time: 0.47s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.44s, Prediction Time: 0.01s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.58, F1-Score: 0.62, ROC-AUC: 0.63, CV Accuracy: 0.61
# Training Time: 0.46s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.44s, Prediction Time: 0.01s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.47s, Prediction Time: 0.01s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.58
# Training Time: 0.45s, Prediction Time: 0.01s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.63, CV Accuracy: 0.58
# Training Time: 0.66s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.55, F1-Score: 0.60, ROC-AUC: 0.64, CV Accuracy: 0.58
# Training Time: 0.44s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 0.71s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.73, F1-Score: 0.69, ROC-AUC: 0.66, CV Accuracy: 0.74
# Training Time: 0.65s, Prediction Time: 0.02s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.76, F1-Score: 0.70, ROC-AUC: 0.66, CV Accuracy: 0.76
# Training Time: 0.72s, Prediction Time: 0.02s
#
# ...
# Training Time: 1.74s, Prediction Time: 0.09s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 1.60s, Prediction Time: 0.07s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 5.20s, Prediction Time: 0.77s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.70, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 1.13s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 1.12s, Prediction Time: 0.04s
#
# Testing: n_estimators=50, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.70, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 1.18s, Prediction Time: 0.05s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 4.76s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 3.83s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 3.66s, Prediction Time: 0.17s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 3.32s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 3.18s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.67, CV Accuracy: 0.72
# Training Time: 3.03s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 3.26s, Prediction Time: 0.15s
#
# Testing: n_estimators=100, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.67, CV Accuracy: 0.72
# Training Time: 2.96s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.53, F1-Score: 0.58, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 1.99s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 2.09s, Prediction Time: 0.07s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.53, F1-Score: 0.58, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 1.96s, Prediction Time: 0.08s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 2.34s, Prediction Time: 0.06s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 2.33s, Prediction Time: 0.07s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.52, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 1.94s, Prediction Time: 0.08s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 1.85s, Prediction Time: 0.14s
#
# Testing: n_estimators=100, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.52, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 2.12s, Prediction Time: 0.07s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 6.56s, Prediction Time: 0.19s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 3.84s, Prediction Time: 0.10s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.75
# Training Time: 4.03s, Prediction Time: 0.13s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 4.06s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 3.84s, Prediction Time: 0.11s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 3.31s, Prediction Time: 0.12s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 6.08s, Prediction Time: 0.46s
#
# Testing: n_estimators=100, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 3.01s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.69, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 6.98s, Prediction Time: 0.27s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 5.88s, Prediction Time: 0.21s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.69, ROC-AUC: 0.67, CV Accuracy: 0.75
# Training Time: 7.74s, Prediction Time: 0.28s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 13.71s, Prediction Time: 0.37s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 6.64s, Prediction Time: 0.28s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 5.57s, Prediction Time: 0.21s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.73
# Training Time: 6.12s, Prediction Time: 0.22s
#
# Testing: n_estimators=200, max_depth=None, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.68, CV Accuracy: 0.72
# Training Time: 5.48s, Prediction Time: 0.23s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.53, F1-Score: 0.59, ROC-AUC: 0.66, CV Accuracy: 0.55
# Training Time: 5.88s, Prediction Time: 0.51s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 4.21s, Prediction Time: 0.13s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.53, F1-Score: 0.59, ROC-AUC: 0.66, CV Accuracy: 0.55
# Training Time: 3.96s, Prediction Time: 0.13s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.51, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 3.85s, Prediction Time: 0.13s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.52, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 3.77s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 4.21s, Prediction Time: 0.12s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.52, F1-Score: 0.57, ROC-AUC: 0.67, CV Accuracy: 0.54
# Training Time: 4.12s, Prediction Time: 0.14s
#
# Testing: n_estimators=200, max_depth=10, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.50, F1-Score: 0.56, ROC-AUC: 0.67, CV Accuracy: 0.53
# Training Time: 4.35s, Prediction Time: 0.22s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 7.13s, Prediction Time: 0.22s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 4.93s, Prediction Time: 0.19s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=1
# Accuracy: 0.74, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.75
# Training Time: 11.32s, Prediction Time: 0.44s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=2, max_features=log2, min_samples_leaf=2
# Accuracy: 0.72, F1-Score: 0.70, ROC-AUC: 0.69, CV Accuracy: 0.72
# Training Time: 6.20s, Prediction Time: 0.24s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 7.40s, Prediction Time: 0.39s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=sqrt, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 4.12s, Prediction Time: 0.15s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=1
# Accuracy: 0.72, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.73
# Training Time: 7.07s, Prediction Time: 0.26s
#
# Testing: n_estimators=200, max_depth=20, min_samples_split=5, max_features=log2, min_samples_leaf=2
# Accuracy: 0.71, F1-Score: 0.69, ROC-AUC: 0.69, CV Accuracy: 0.71
# Training Time: 4.56s, Prediction Time: 0.15s
#
# Summary of Results:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 0             50        NaN                  2         sqrt                 1
# 1             50        NaN                  2         sqrt                 2
# 2             50        NaN                  2         log2                 1
# 3             50        NaN                  2         log2                 2
# 4             50        NaN                  5         sqrt                 1
# ..           ...        ...                ...          ...               ...
# 67           200       20.0                  2         log2                 2
# 68           200       20.0                  5         sqrt                 1
# 69           200       20.0                  5         sqrt                 2
# 70           200       20.0                  5         log2                 1
# 71           200       20.0                  5         log2                 2
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time  prediction_time
# 0   0.738162  0.694502  0.665061     0.747075       2.149915         0.068071
# 1   0.711699  0.691682  0.679966     0.717061       1.818524         0.070417
# 2   0.738162  0.694502  0.665061     0.747075       2.138554         0.068151
# 3   0.711699  0.691682  0.679966     0.717061       1.662610         0.121303
# 4   0.720613  0.693075  0.675322     0.726532       1.891983         0.057807
# ..       ...       ...       ...          ...            ...              ...
# 67  0.716435  0.695891  0.688019     0.721727       6.197815         0.236452
# 68  0.718384  0.693776  0.686126     0.727368       7.400200         0.391380
# 69  0.705014  0.690889  0.688564     0.713231       4.119850         0.148271
# 70  0.718384  0.693776  0.686126     0.727368       7.067286         0.256248
# 71  0.705014  0.690889  0.688564     0.713231       4.564990         0.150094
#
# [72 rows x 11 columns]
#
# Top 5 Models:
#      n_estimators  max_depth  min_samples_split max_features  min_samples_leaf  \
# 24           100        NaN                  2         sqrt                 1
# 26           100        NaN                  2         log2                 1
# 48           200        NaN                  2         sqrt                 1
# 50           200        NaN                  2         log2                 1
# 40           100       20.0                  2         sqrt                 1
#
#     accuracy  f1_score   roc_auc  cv_accuracy  training_time
# 24  0.740947  0.695873  0.670106     0.747772       4.764651
# 26  0.740947  0.695873  0.670106     0.747772       3.657190
# 48  0.740947  0.694641  0.672392     0.748816       6.980108
# 50  0.740947  0.694641  0.672392     0.748816       7.736182
# 40  0.738719  0.695737  0.683332     0.746448       6.557352
#
# Holdout vs. CV Accuracy Difference:
#          accuracy  cv_accuracy  holdout_cv_diff
# count  72.000000    72.000000        72.000000
# mean    0.649010     0.661645        -0.012635
# std     0.101825     0.093486         0.009690
# min     0.477716     0.515947        -0.042618
# 25%     0.515877     0.539868        -0.019603
# 50%     0.710028     0.717166        -0.008043
# 75%     0.720752     0.726741        -0.006180
# max     0.740947     0.748816        -0.003134
# Parameter Sensitivity (Std of Accuracy):
# n_estimators:
# n_estimators
# 50     0.109099
# 100    0.099849
# 200    0.100348
# Name: accuracy, dtype: float64
# max_depth:
# max_depth
# 10.0    0.014954
# 20.0    0.012785
# Name: accuracy, dtype: float64
# min_samples_split:
# min_samples_split
# 2    0.104040
# 5    0.100706
# Name: accuracy, dtype: float64
# max_features:
# max_features
# log2    0.10255
# sqrt    0.10255
# Name: accuracy, dtype: float64
# min_samples_leaf:
# min_samples_leaf
# 1    0.103021
# 2    0.101239
# Name: accuracy, dtype: float64
#
# Most Common Parameters in Top 10 Models:
# n_estimators: n_estimators
# 100    4
# Name: count, dtype: int64
# max_depth: max_depth
# 20.0    4
# Name: count, dtype: int64
# min_samples_split: min_samples_split
# 2    10
# Name: count, dtype: int64
# max_features: max_features
# sqrt    5
# Name: count, dtype: int64
# min_samples_leaf: min_samples_leaf
# 1    10
# Name: count, dtype: int64
# Classification Report for Best Model:
#               precision    recall  f1-score   support
#
#      0 Stars       0.43      0.24      0.31       339
#       1 Star       0.35      0.21      0.27        56
#      3 Stars       0.04      0.01      0.02        98
#      4 Stars       0.12      0.04      0.06       331
#      5 Stars       0.79      0.92      0.85      2766
#
#     accuracy                           0.74      3590
#    macro avg       0.35      0.29      0.30      3590
# weighted avg       0.67      0.74      0.70      3590
